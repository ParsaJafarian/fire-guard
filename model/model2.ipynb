# %%
import pandas as pd

# %% [markdown]
# `clean-weather.csv` contains the weather/wildfire data after having being thoroughly processed and cleaned in `data-cleaning-preparation.ipnyb`.

# %%
df = pd.read_csv('clean-weather-2.csv')

# %%
df.head()
# Out:
#    LATITUDE  LONGITUDE  ELEVATION    STATION_NAME PROVINCE_CODE  \
# 0   50.9050  -126.9292       14.0      EGG ISLAND            BC
# 1   59.9617  -121.3608      498.0      SAMBAA K'E            NT
# 2   59.9752  -121.0342      498.0      SAMBAA K'E            NT
# 3   59.1767  -122.0190      378.3  FORT NELSON UA            BC
# 4   59.4008  -120.6438      777.2      PETITOT LO            AB
#
#                   ID           LOCAL_DATE  LOCAL_DAY  LOCAL_MONTH  LOCAL_YEAR  \
# 0  1062646.2000.3.10  2000-03-10 00:00:00       10.0          3.0      2000.0
# 1  220CQHR.2000.6.27  2000-06-27 00:00:00       27.0          6.0      2000.0
# 2  220CQHR.2000.7.11  2000-07-11 00:00:00       11.0          7.0      2000.0
# 3  1192950.2001.6.13  2001-06-13 00:00:00       13.0          6.0      2001.0
# 4  3075171.2000.6.26  2000-06-26 00:00:00       26.0          6.0      2000.0
#
#    MIN_TEMPERATURE  MAX_TEMPERATURE  MEAN_TEMPERATURE  SNOW_ON_GROUND  \
# 0              2.0             11.3               6.7             0.0
# 1              7.9             27.0              17.5             0.0
# 2              9.9             20.9              15.4             0.0
# 3              8.5             26.8              17.7             0.0
# 4              8.0             24.0              16.0             0.0
#
#    TOTAL_SNOW  TOTAL_PRECIPITATION  TOTAL_RAIN  hectares
# 0         0.0                  3.5         3.5       6.0
# 1         0.0                  0.0         0.0    1000.0
# 2         0.0                  0.0         0.0      12.0
# 3         0.0                  0.0         0.0       5.0
# 4         0.0                  1.2         1.2       0.1

# %%
df.describe()
# Out:
#            LATITUDE     LONGITUDE     ELEVATION    LOCAL_DAY   LOCAL_MONTH  \
# count  59732.000000  59732.000000  59572.000000  59732.00000  59732.000000
# mean      52.430932   -101.861180    498.738882     15.50437      5.835147
# std        4.680110     20.590721    389.618273      8.80355      1.794696
# min       40.065300   -162.480000      1.200000      1.00000      1.000000
# 25%       49.230000   -117.542833    226.125000      8.00000      5.000000
# 50%       51.958800   -110.581933    390.800000     15.00000      6.000000
# 75%       55.411950    -85.678991    683.300000     23.00000      7.000000
# max       82.310400    116.188000   2926.100000     31.00000     12.000000
#
#          LOCAL_YEAR  MIN_TEMPERATURE  MAX_TEMPERATURE  MEAN_TEMPERATURE  \
# count  59732.000000     59732.000000     59732.000000      59732.000000
# mean    2009.038204         4.713177        18.190861         11.467476
# std        6.677045         8.798398         9.858715          8.986341
# min     1999.000000       -46.900000       -42.700000        -44.800000
# 25%     2003.000000        -0.100000        12.600000          6.500000
# 50%     2007.000000         6.100000        20.000000         13.400000
# 75%     2014.000000        11.000000        25.400000         18.000000
# max     2024.000000        26.500000        47.900000         34.400000
#
#        SNOW_ON_GROUND    TOTAL_SNOW  TOTAL_PRECIPITATION    TOTAL_RAIN  \
# count    59732.000000  59732.000000         59732.000000  59732.000000
# mean         2.705826      0.106384             1.673659      1.125370
# std         12.224479      1.051774             4.796884      4.046445
# min          0.000000      0.000000             0.000000      0.000000
# 25%          0.000000      0.000000             0.000000      0.000000
# 50%          0.000000      0.000000             0.000000      0.000000
# 75%          0.000000      0.000000             0.900000      0.000000
# max        322.000000     38.600000           168.000000    168.000000
#
#             hectares
# count   59732.000000
# mean      248.934998
# std      5267.998994
# min         0.000000
# 25%         0.000000
# 50%         0.009000
# 75%         0.200000
# max    577646.800000

# %% [markdown]
# # Modeling
# It is not evident which model would best be used for our dataset, so we perform simple tests to see if basic models might be viable using a single test-train split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error

# %%
x = df[['LATITUDE', 'LONGITUDE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MIN_TEMPERATURE', 'SNOW_ON_GROUND', 'TOTAL_SNOW', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY', 'SPEED_MAX_GUST']] # Only select weather data
# x = df[['MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MIN_TEMPERATURE', 'SNOW_ON_GROUND', 'TOTAL_SNOW', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN']] # Only select weather data
y = df['hectares']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 x = df[['LATITUDE', 'LONGITUDE', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MIN_TEMPERATURE', 'SNOW_ON_GROUND', 'TOTAL_SNOW', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN', 'MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY', 'SPEED_MAX_GUST']] # Only select weather data
#       2 # x = df[['MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MIN_TEMPERATURE', 'SNOW_ON_GROUND', 'TOTAL_SNOW', 'TOTAL_PRECIPITATION', 'TOTAL_RAIN']] # Only select weather data
#       3 y = df['hectares']
#
# File ~\PycharmProjects\fire-guard\model\venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\PycharmProjects\fire-guard\model\venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~\PycharmProjects\fire-guard\model\venv\Lib\site-packages\pandas\core\indexes\base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY', 'SPEED_MAX_GUST'] not in index"

# %% [markdown]
# ## Linear Regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)

# %%
# Predicting on the train set
y_pred = model.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %%
y_train_pred = model.predict(x_train)

# %%
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)

# %%
# Predicting on the test set
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %%
# Predicting on train set
y_train_pred = model.predict(x_train)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %% [markdown]
# Decision Tree Regressor has overfit

# %% [markdown]
# ## Random Forests Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()
model.fit(x_train, y_train)

# %%
# Predicting on the test set
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %%
# Predicting on train set
y_train_pred = model.predict(x_train)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %% [markdown]
# ## Gradient Boosting Model

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model = GradientBoostingRegressor()
model.fit(x_train, y_train)

# %%
# Predicting on the test set
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
# Out:
# MAE: 334.4183058567978
# MSE: 43989679.45379763
# RMSE: 6632.471594646872
# R²: -0.0025468410102185146

# %%
# Predicting on train set
y_train_pred = model.predict(x_train)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %% [markdown]
# ## K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor()
model.fit(x_train, y_train)

# %%
# Predicting on the test set
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %%
# Predicting on train set
y_train_pred = model.predict(x_train)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVR

# %%
model = SVR()
model.fit(x_train, y_train)

# %%
# Predicting on the test set
y_pred = model.predict(x_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")

# %%
# Predicting on train set
y_train_pred = model.predict(x_train)
mae = mean_absolute_error(y_train, y_train_pred)
mse = mean_squared_error(y_train, y_train_pred)
rmse = root_mean_squared_error(y_train, y_train_pred)
r2 = r2_score(y_train, y_train_pred)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R²: {r2}")
