# %% [markdown]
# # Data cleaning and preparation
# This notebook was used to perform analysis on missing data, imputation, removing duplicates, cleaning, preprocessing, feature selection, and merging weather data for points with (>0) and without wildfires (=0) by using datasets found in `fires-no-weather.csv` and `fires-weather.csv`. The former contains weather data for points that are not associated with wildfires, they were queried by using wildfire locations 50 days prior and by querying stations that were not associated with any wildfire. The latter queries the weather data for the 140000+ wildfire points in the wildfire dataset. Details on how they were obtained can be found in the `get-weather-data.ipnyb` notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset
# The glossary for some of the column meanings can be found [here](https://climate.weather.gc.ca/glossary_e.html)

# %%
no_wildfire_df = pd.read_csv('fires-no-weather.csv')
# Out:
# C:\Users\ethan\AppData\Local\Temp\ipykernel_2340\2162425656.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   no_wildfire_df = pd.read_csv('fires-no-weather.csv')

# %%
no_wildfire_df
# Out:
#        hectares       STATION_NAME PROV_STATE_TERR_CODE  LATITUDE   LONGITUDE  \
# 0             0         EGG ISLAND                   BC   51.1450 -127.500730
# 1             0         SAMBAA K'E                   NT   60.2627 -121.142000
# 2             0         SAMBAA K'E                   NT   60.2627 -121.142000
# 3             0     FORT NELSON UA                   BC   58.5029 -122.342207
# 4             0         PETITOT LO                   AB   59.3200 -119.370000
# ...         ...                ...                  ...       ...         ...
# 34060         0          YOHO PARK                  NaN       NaN         NaN
# 34061         0          YORKTON A                  NaN       NaN         NaN
# 34062         0  YORKTON RCMP SNOW                  NaN       NaN         NaN
# 34063         0    YOUNGSTOWN AGCM                  NaN       NaN         NaN
# 34064         0    YOUNGSTOWN AGCM                  NaN       NaN         NaN
#
#        ELEVATION  LOCAL_MONTH  LOCAL_DAY  DIRECTION_MAX_GUST  \
# 0           14.0          1.0       20.0                 NaN
# 1          498.0          5.0        8.0                 NaN
# 2          498.0          5.0       22.0                 NaN
# 3          378.3          4.0       24.0                 NaN
# 4          777.2          5.0        7.0                 NaN
# ...          ...          ...        ...                 ...
# 34060        NaN          8.0        2.0                 NaN
# 34061        NaN          2.0       19.0                 0.0
# 34062        NaN          1.0       31.0                 NaN
# 34063        NaN          6.0       25.0                21.0
# 34064        NaN          6.0       25.0                21.0
#
#       MIN_REL_HUMIDITY_FLAG  ...  HEATING_DEGREE_DAYS_FLAG TOTAL_SNOW_FLAG  \
# 0                       NaN  ...                       NaN             NaN
# 1                       NaN  ...                       NaN             NaN
# 2                       NaN  ...                       NaN             NaN
# 3                       NaN  ...                       NaN             NaN
# 4                       NaN  ...                         M               M
# ...                     ...  ...                       ...             ...
# 34060                   NaN  ...                         M               M
# 34061                     M  ...                       NaN             NaN
# 34062                   NaN  ...                       NaN             NaN
# 34063                   NaN  ...                       NaN             NaN
# 34064                   NaN  ...                       NaN             NaN
#
#                 LOCAL_DATE MIN_TEMPERATURE PROVINCE_CODE  SPEED_MAX_GUST_FLAG  \
# 0      2000-01-20 00:00:00            -1.3            BC                  NaN
# 1      2000-05-08 00:00:00            -2.2            NT                  NaN
# 2      2000-05-22 00:00:00            -0.9            NT                  NaN
# 3      2001-04-24 00:00:00             0.4            BC                  NaN
# 4      2000-05-07 00:00:00             NaN            AB                  NaN
# ...                    ...             ...           ...                  ...
# 34060  2000-08-02 00:00:00             NaN            BC                    M
# 34061  2000-02-19 00:00:00           -16.5            SK                  NaN
# 34062  2010-01-31 00:00:00             NaN            SK                  NaN
# 34063  2018-06-25 00:00:00            14.3            AB                  NaN
# 34064  2018-06-25 00:00:00            14.3            AB                  NaN
#
#       SPEED_MAX_GUST  MAX_TEMPERATURE  MEAN_TEMPERATURE_FLAG  \
# 0                NaN              3.3                    NaN
# 1                NaN             14.5                    NaN
# 2                NaN             15.1                    NaN
# 3                NaN             18.5                    NaN
# 4                NaN              NaN                      M
# ...              ...              ...                    ...
# 34060            NaN              NaN                      M
# 34061            0.0             -2.7                    NaN
# 34062            NaN              NaN                    NaN
# 34063           44.0             31.2                    NaN
# 34064           44.0             31.2                    NaN
#
#       SNOW_ON_GROUND_FLAG
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 34060                 NaN
# 34061                 NaN
# 34062                 NaN
# 34063                 NaN
# 34064                 NaN
#
# [34065 rows x 39 columns]

# %%
wildfire_df = pd.read_csv('fires-weather.csv')
# Out:
# C:\Users\ethan\AppData\Local\Temp\ipykernel_2340\885837184.py:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   wildfire_df = pd.read_csv('fires-weather.csv')

# %%
wildfire_df
# Out:
#         fire_id      lat       lon        date  hectares  \
# 0             0  50.9050 -126.9292  2000-03-10      6.00
# 1             1  49.2971 -122.2321  2000-08-21      0.20
# 2             2  55.8000 -124.8167  2005-06-20      0.01
# 3             3  49.8770 -121.5730  2000-08-06      0.10
# 4             4  49.0667 -121.8333  2000-07-28      0.10
# ...         ...      ...       ...         ...       ...
# 148758   148756  65.0282 -141.2460  2024-05-15      0.00
# 148759   148757  55.9370 -121.9170  2024-05-12    295.00
# 148760   148758  60.2150 -112.8720  2024-04-26      0.10
# 148761   148759  60.1950 -112.7960  2024-04-26      0.10
# 148762   148760  60.3920 -117.8960  2024-05-05      3.00
#
#                  STATION_NAME PROV_STATE_TERR_CODE  LATITUDE  LONGITUDE  \
# 0                  EGG ISLAND                   BC   51.1450 -127.50073
# 1                   PITT LAKE                   BC   49.2600 -122.31000
# 2              MESILINKA CAMP                   BC   56.0700 -124.30000
# 3                    LYTTON A                   BC   50.1328 -121.34550
# 4        VEDDER SOUTH LICKMAN                   BC   49.0600 -122.00000
# ...                       ...                  ...       ...        ...
# 148758          CLINTON CREEK                   YT   64.2800 -140.44000
# 148759  HUDSON HOPE BCHPA DAM                   BC   56.0100 -122.12000
# 148760             BEAR TOWER                   NT   60.3100 -113.14000
# 148761             BEAR TOWER                   NT   60.3100 -113.14000
# 148762          CAMERON HILLS                   NT   60.1800 -117.03000
#
#         ELEVATION  ...  TOTAL_PRECIPITATION_FLAG SPEED_MAX_GUST_FLAG  \
# 0            14.0  ...                       NaN                 NaN
# 1             7.6  ...                       NaN                 NaN
# 2           803.0  ...                       NaN                 NaN
# 3           224.9  ...                       NaN                 NaN
# 4            15.2  ...                       NaN                 NaN
# ...           ...  ...                       ...                 ...
# 148758      576.1  ...                       NaN                 NaN
# 148759      678.2  ...                       NaN                 NaN
# 148760      213.4  ...                       NaN                 NaN
# 148761      213.4  ...                       NaN                 NaN
# 148762      841.2  ...                       NaN                 NaN
#
#         LOCAL_YEAR TOTAL_RAIN MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  \
# 0           2000.0        3.5                   NaN              NaN
# 1              NaN        NaN                   NaN              NaN
# 2              NaN        NaN                   NaN              NaN
# 3              NaN        NaN                   NaN              NaN
# 4              NaN        NaN                   NaN              NaN
# ...            ...        ...                   ...              ...
# 148758         NaN        NaN                   NaN              NaN
# 148759         NaN        NaN                   NaN              NaN
# 148760         NaN        NaN                   NaN              NaN
# 148761         NaN        NaN                   NaN              NaN
# 148762         NaN        NaN                   NaN              NaN
#
#         HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 0                            NaN                  3.5             0.0
# 1                            NaN                  NaN             NaN
# 2                            NaN                  NaN             NaN
# 3                            NaN                  NaN             NaN
# 4                            NaN                  NaN             NaN
# ...                          ...                  ...             ...
# 148758                       NaN                  NaN             NaN
# 148759                       NaN                  NaN             NaN
# 148760                       NaN                  NaN             NaN
# 148761                       NaN                  NaN             NaN
# 148762                       NaN                  NaN             NaN
#
#        CLIMATE_IDENTIFIER
# 0                 1062646
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 148758                NaN
# 148759                NaN
# 148760                NaN
# 148761                NaN
# 148762                NaN
#
# [148763 rows x 44 columns]

# %% [markdown]
# Columns have mixed types

# %%
# Function to check mixed types in columns, returns a dictionary where keys are column names, values are lists of types
def check_mixed_types(df):
    mixed_type_columns = {}
    for column in df.columns:
        types = df[column].map(type).unique()
        if len(types) > 1:
            mixed_type_columns[column] = types
    return mixed_type_columns

# %%
mixed_types = check_mixed_types(wildfire_df)

for k, v in mixed_types.items():
    print(k, v)
# Out:
# PROVINCE_CODE [<class 'str'> <class 'float'>]
# TOTAL_SNOW_FLAG [<class 'float'> <class 'str'>]
# DIRECTION_MAX_GUST_FLAG [<class 'float'> <class 'str'>]
# ID [<class 'str'> <class 'float'>]
# MIN_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# MAX_REL_HUMIDITY_FLAG [<class 'float'> <class 'str'>]
# LOCAL_DATE [<class 'str'> <class 'float'>]
# COOLING_DEGREE_DAYS_FLAG [<class 'float'> <class 'str'>]
# SNOW_ON_GROUND_FLAG [<class 'float'> <class 'str'>]
# MEAN_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# MAX_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# TOTAL_PRECIPITATION_FLAG [<class 'float'> <class 'str'>]
# SPEED_MAX_GUST_FLAG [<class 'float'> <class 'str'>]
# MIN_REL_HUMIDITY_FLAG [<class 'float'> <class 'str'>]
# TOTAL_RAIN_FLAG [<class 'float'> <class 'str'>]
# HEATING_DEGREE_DAYS_FLAG [<class 'float'> <class 'str'>]
# CLIMATE_IDENTIFIER [<class 'str'> <class 'float'>]

# %%
mixed_types = check_mixed_types(no_wildfire_df)

for k, v in mixed_types.items():
    print(k, v)
# Out:
# PROV_STATE_TERR_CODE [<class 'str'> <class 'float'>]
# MIN_REL_HUMIDITY_FLAG [<class 'float'> <class 'str'>]
# DIRECTION_MAX_GUST_FLAG [<class 'float'> <class 'str'>]
# COOLING_DEGREE_DAYS_FLAG [<class 'float'> <class 'str'>]
# MAX_REL_HUMIDITY_FLAG [<class 'float'> <class 'str'>]
# TOTAL_PRECIPITATION_FLAG [<class 'float'> <class 'str'>]
# MIN_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# MAX_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# TOTAL_RAIN_FLAG [<class 'float'> <class 'str'>]
# HEATING_DEGREE_DAYS_FLAG [<class 'float'> <class 'str'>]
# TOTAL_SNOW_FLAG [<class 'float'> <class 'str'>]
# SPEED_MAX_GUST_FLAG [<class 'float'> <class 'str'>]
# MEAN_TEMPERATURE_FLAG [<class 'float'> <class 'str'>]
# SNOW_ON_GROUND_FLAG [<class 'float'> <class 'str'>]

# %%
# Check PROVINCE_CODE
value_provinces = wildfire_df['PROVINCE_CODE']
value_str_provinces = value_provinces.apply(lambda x: isinstance(x, str))

# %%
province_mix = pd.concat([value_provinces, value_str_provinces], axis=1)
province_mix.columns = ['PROVINCE_CODE', 'IS_STR']
province_mix
# Out:
#        PROVINCE_CODE  IS_STR
# 0                 BC    True
# 1                NaN   False
# 2                NaN   False
# 3                NaN   False
# 4                NaN   False
# ...              ...     ...
# 148758           NaN   False
# 148759           NaN   False
# 148760           NaN   False
# 148761           NaN   False
# 148762           NaN   False
#
# [148763 rows x 2 columns]

# %% [markdown]
# Conclusion: `NaN` values are treated as floats, which are not string, so we force type conversion

# %%
types = {
    'PROV_STATE_TERR_CODE': 'str',
    'PROVINCE_CODE': 'str',
    'TOTAL_SNOW_FLAG': 'str',
    'DIRECTION_MAX_GUST_FLAG': 'str',
    'ID': 'str',
    'MIN_TEMPERATURE_FLAG': 'str',
    'MAX_TEMPERATURE_FLAG': 'str',
    'LOCAL_DATE': 'str',
    'COOLING_DEGREE_DAYS_FLAG': 'str',
    'SNOW_ON_GROUND_FLAG': 'str',
    'MEAN_TEMPERATURE_FLAG': 'str',
    'TOTAL_PRECIPITATION_FLAG': 'str',
}

# %%
wildfire_df = pd.read_csv('fires-weather.csv', dtype=types)

# %%
no_wildfire_df = pd.read_csv('fires-no-weather.csv', dtype=types)

# %% [markdown]
# ## Duplicates
# Checking for duplicate `ID`s because merging caused miss-indexing

# %%
# Check for duplicate fire_id because indexing is wrong in the file
duplicates = wildfire_df[wildfire_df['fire_id'].duplicated(keep=False)]
duplicates
# Out:
#         fire_id      lat      lon        date  hectares     STATION_NAME  \
# 32682     32682  53.5645 -123.940  2018-06-23     144.1            MAPES
# 32683     32682  53.5645 -123.940  2018-06-23     144.1  FORT FRASER 13S
# 145995   145994  48.2770  -80.545  2023-06-23       1.9        CONNAUGHT
# 145996   145994  48.2770  -80.545  2023-06-23       1.9        CONNAUGHT
#
#        PROV_STATE_TERR_CODE  LATITUDE  LONGITUDE  ELEVATION  ...  \
# 32682                    BC     53.53    -123.53      784.9  ...
# 32683                    BC     53.53    -124.35      701.0  ...
# 145995                   ON     48.37     -80.55      281.3  ...
# 145996                   ON     48.37     -80.54      281.3  ...
#
#         TOTAL_PRECIPITATION_FLAG SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 32682                        NaN                 NaN         NaN        NaN
# 32683                        NaN                 NaN         NaN        NaN
# 145995                       NaN                 NaN         NaN        NaN
# 145996                       NaN                 NaN         NaN        NaN
#
#        MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 32682                    NaN              NaN                       NaN
# 32683                    NaN              NaN                       NaN
# 145995                   NaN              NaN                       NaN
# 145996                   NaN              NaN                       NaN
#
#         TOTAL_PRECIPITATION  SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 32682                   NaN             NaN                NaN
# 32683                   NaN             NaN                NaN
# 145995                  NaN             NaN                NaN
# 145996                  NaN             NaN                NaN
#
# [4 rows x 44 columns]

# %%
# Drop duplicates for wildfire weather
wildfire_df = wildfire_df.drop_duplicates(subset='fire_id')

# %%
# Drop duplicates for no wildfire weather
no_wildfire_df = no_wildfire_df.drop_duplicates(subset='ID')

# %%
no_wildfire_df.head()
# Out:
#    hectares    STATION_NAME PROV_STATE_TERR_CODE  LATITUDE   LONGITUDE  \
# 0         0      EGG ISLAND                   BC   51.1450 -127.500730
# 1         0      SAMBAA K'E                   NT   60.2627 -121.142000
# 2         0      SAMBAA K'E                   NT   60.2627 -121.142000
# 3         0  FORT NELSON UA                   BC   58.5029 -122.342207
# 4         0      PETITOT LO                   AB   59.3200 -119.370000
#
#    ELEVATION  LOCAL_MONTH  LOCAL_DAY  DIRECTION_MAX_GUST  \
# 0       14.0          1.0       20.0                 NaN
# 1      498.0          5.0        8.0                 NaN
# 2      498.0          5.0       22.0                 NaN
# 3      378.3          4.0       24.0                 NaN
# 4      777.2          5.0        7.0                 NaN
#
#   MIN_REL_HUMIDITY_FLAG  ...  HEATING_DEGREE_DAYS_FLAG TOTAL_SNOW_FLAG  \
# 0                   NaN  ...                       NaN             NaN
# 1                   NaN  ...                       NaN             NaN
# 2                   NaN  ...                       NaN             NaN
# 3                   NaN  ...                       NaN             NaN
# 4                   NaN  ...                         M               M
#
#             LOCAL_DATE MIN_TEMPERATURE PROVINCE_CODE  SPEED_MAX_GUST_FLAG  \
# 0  2000-01-20 00:00:00            -1.3            BC                  NaN
# 1  2000-05-08 00:00:00            -2.2            NT                  NaN
# 2  2000-05-22 00:00:00            -0.9            NT                  NaN
# 3  2001-04-24 00:00:00             0.4            BC                  NaN
# 4  2000-05-07 00:00:00             NaN            AB                  NaN
#
#   SPEED_MAX_GUST  MAX_TEMPERATURE  MEAN_TEMPERATURE_FLAG SNOW_ON_GROUND_FLAG
# 0            NaN              3.3                    NaN                 NaN
# 1            NaN             14.5                    NaN                 NaN
# 2            NaN             15.1                    NaN                 NaN
# 3            NaN             18.5                    NaN                 NaN
# 4            NaN              NaN                      M                 NaN
#
# [5 rows x 39 columns]

# %%
wildfire_df.head()
# Out:
#    fire_id      lat       lon        date  hectares          STATION_NAME  \
# 0        0  50.9050 -126.9292  2000-03-10      6.00            EGG ISLAND
# 1        1  49.2971 -122.2321  2000-08-21      0.20             PITT LAKE
# 2        2  55.8000 -124.8167  2005-06-20      0.01        MESILINKA CAMP
# 3        3  49.8770 -121.5730  2000-08-06      0.10              LYTTON A
# 4        4  49.0667 -121.8333  2000-07-28      0.10  VEDDER SOUTH LICKMAN
#
#   PROV_STATE_TERR_CODE  LATITUDE  LONGITUDE  ELEVATION  ...  \
# 0                   BC   51.1450 -127.50073       14.0  ...
# 1                   BC   49.2600 -122.31000        7.6  ...
# 2                   BC   56.0700 -124.30000      803.0  ...
# 3                   BC   50.1328 -121.34550      224.9  ...
# 4                   BC   49.0600 -122.00000       15.2  ...
#
#    TOTAL_PRECIPITATION_FLAG SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 0                       NaN                 NaN      2000.0        3.5
# 1                       NaN                 NaN         NaN        NaN
# 2                       NaN                 NaN         NaN        NaN
# 3                       NaN                 NaN         NaN        NaN
# 4                       NaN                 NaN         NaN        NaN
#
#   MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 0                   NaN              NaN                       NaN
# 1                   NaN              NaN                       NaN
# 2                   NaN              NaN                       NaN
# 3                   NaN              NaN                       NaN
# 4                   NaN              NaN                       NaN
#
#    TOTAL_PRECIPITATION  SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 0                  3.5             0.0            1062646
# 1                  NaN             NaN                NaN
# 2                  NaN             NaN                NaN
# 3                  NaN             NaN                NaN
# 4                  NaN             NaN                NaN
#
# [5 rows x 44 columns]

# %%
no_wildfire_df.describe()
# Out:
#        hectares      LATITUDE     LONGITUDE     ELEVATION   LOCAL_MONTH  \
# count   27056.0  25600.000000  25600.000000  25318.000000  27056.000000
# mean        0.0     52.118178   -101.053435    483.194036      4.985770
# std         0.0      4.772847     21.272203    398.584617      1.765598
# min         0.0     42.020000   -140.520800      1.200000      1.000000
# 25%         0.0     49.020000   -117.531200    213.400000      4.000000
# 50%         0.0     51.315700   -109.574308    379.200000      5.000000
# 75%         0.0     55.122500    -82.040000    669.000000      6.000000
# max         0.0     82.310400    -52.490100   2926.100000     12.000000
#
#           LOCAL_DAY  DIRECTION_MAX_GUST    LOCAL_YEAR  MIN_REL_HUMIDITY  \
# count  27056.000000         8837.000000  27056.000000       6503.000000
# mean      15.569892           12.305534   2009.091255         46.362141
# std        8.663849           12.973155      6.778802         18.613342
# min        1.000000            0.000000   1999.000000          9.000000
# 25%        8.000000            0.000000   2003.000000         32.000000
# 50%       16.000000            7.000000   2007.000000         44.000000
# 75%       23.000000           25.000000   2014.000000         59.000000
# max       31.000000           36.000000   2024.000000        100.000000
#
#          TOTAL_RAIN  COOLING_DEGREE_DAYS  MEAN_TEMPERATURE  \
# count  16232.000000         24346.000000      24346.000000
# mean       1.592558             0.300854          6.847835
# std        4.927716             1.108816         10.061779
# min        0.000000             0.000000        -42.700000
# 25%        0.000000             0.000000          0.500000
# 50%        0.000000             0.000000          8.400000
# 75%        0.500000             0.000000         14.500000
# max      104.800000            16.400000         34.400000
#
#        HEATING_DEGREE_DAYS  TOTAL_PRECIPITATION    TOTAL_SNOW  SNOW_ON_GROUND  \
# count         24346.000000         23669.000000  16206.000000    15449.000000
# mean             11.453019             1.876514      0.359663       10.071014
# std               9.649780             5.086972      1.897399       21.768192
# min               0.000000             0.000000      0.000000        0.000000
# 25%               3.500000             0.000000      0.000000        0.000000
# 50%               9.600000             0.000000      0.000000        0.000000
# 75%              17.500000             1.200000      0.000000        9.000000
# max              60.700000           104.800000     38.600000      322.000000
#
#        MAX_REL_HUMIDITY  MIN_TEMPERATURE  SPEED_MAX_GUST  MAX_TEMPERATURE
# count       6505.000000      25091.00000     8862.000000     25144.000000
# mean          88.438432          0.68177       25.097269        13.011637
# std           10.304673          9.95721       22.387242        10.764646
# min           33.000000        -45.00000        0.000000       -41.300000
# 25%           83.000000         -4.50000        0.000000         5.300000
# 50%           91.000000          2.00000       33.000000        14.300000
# 75%           96.000000          8.00000       41.000000        21.500000
# max          100.000000         26.50000      149.000000        47.900000

# %%
wildfire_df.describe()
# Out:
#              fire_id            lat            lon      hectares  \
# count  148761.000000  148761.000000  148761.000000  1.487610e+05
# mean    74380.000000      52.032307    -102.520121  4.641035e+02
# std     42943.746035       4.754563      20.945083  7.872712e+03
# min         0.000000       0.000000    -166.044000  0.000000e+00
# 25%     37190.000000      49.101900    -118.704167  1.000000e-02
# 50%     74380.000000      51.332000    -112.104017  1.000000e-01
# 75%    111570.000000      55.153550     -84.693700  1.000000e+00
# max    148760.000000      69.602500     116.188000  1.080520e+06
#
#             LATITUDE      LONGITUDE      ELEVATION       distance  \
# count  148761.000000  148761.000000  146037.000000  148761.000000
# mean       52.008772    -102.518765     533.722164      24.676222
# std         4.755300      20.902612     418.085939      39.763070
# min         0.000000    -141.000000       0.000000       0.000000
# 25%        49.130000    -118.550000     245.000000      10.530787
# 50%        51.265700    -112.130000     420.600000      19.641312
# 75%        55.180000     -84.480000     731.500000      31.307892
# max        82.310400       0.000000    2926.100000    5679.881861
#
#        HEATING_DEGREE_DAYS  DIRECTION_MAX_GUST  ...    TOTAL_SNOW  \
# count         31956.000000         10800.00000  ...  23220.000000
# mean              3.947835            14.12787  ...      0.030177
# std               5.152374            12.93195  ...      0.565366
# min               0.000000             0.00000  ...      0.000000
# 25%               0.000000             0.00000  ...      0.000000
# 50%               1.700000            15.00000  ...      0.000000
# 75%               6.500000            26.00000  ...      0.000000
# max              62.800000            36.00000  ...     37.000000
#
#        MEAN_TEMPERATURE  SPEED_MAX_GUST  MIN_REL_HUMIDITY  \
# count      31956.000000    10839.000000       7868.000000
# mean          15.153085       28.035335         38.224962
# std            6.253920       22.567243         15.494066
# min          -44.800000        0.000000          8.000000
# 25%           11.500000        0.000000         27.000000
# 50%           16.300000       35.000000         36.000000
# 75%           19.500000       44.000000         47.000000
# max           31.800000      128.000000        100.000000
#
#        COOLING_DEGREE_DAYS  MAX_TEMPERATURE    LOCAL_YEAR    TOTAL_RAIN  \
# count         31956.000000     33675.000000  35958.000000  23018.000000
# mean              1.100920        22.310218   2008.928305      1.933739
# std               1.967685         6.921212      6.554949      5.041713
# min               0.000000       -42.700000   2000.000000      0.000000
# 25%               0.000000        18.400000   2004.000000      0.000000
# 50%               0.000000        23.300000   2007.000000      0.000000
# 75%               1.500000        27.000000   2014.000000      1.400000
# max              13.800000        45.500000   2024.000000    168.000000
#
#        TOTAL_PRECIPITATION  SNOW_ON_GROUND
# count         32290.000000    20168.000000
# mean              1.847290        0.400352
# std               4.988779        5.295837
# min               0.000000        0.000000
# 25%               0.000000        0.000000
# 50%               0.000000        0.000000
# 75%               1.200000        0.000000
# max             168.000000      254.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# Notice the `distance` column, which represents the distance between the actual wildfire location and the location of the station where weather data was collected. It averages around 25km which is not bad, and the max distance between wildfire and a station is 5679km, which is not great but still acceptable. However, the 75% percentile is at 31km and 50% percentile at 20km, meaning that there are a few outliers that are skewing the average higher

# %% [markdown]
# ## Merge no-wildfire and wildfire dataset
# Now that we have both datasets, we want to concatenate them into a single dataframe that we can work with for training the model. Notice that in the wildfire dataset, we have columns that do not exist in the non-wildfire dataset. These include `fire_id`, `lat`, `lon` (coords of actual wildfire location, whereas `LATITUDE` and `LONGITUDE` are the nearest station locations),  `distance`. Since every data point only has one coordinate, we choose to override the station location with the wildfire location

# %%
# Override station location with wildfire location
wildfire_df['LATITUDE'] = wildfire_df['lat']
wildfire_df['LONGITUDE'] = wildfire_df['lon']

# %%
# Also override duplicate PROV_STATE_TERR_CODE from wildfire dataset
wildfire_df['PROVINCE_CODE'] = wildfire_df['PROV_STATE_TERR_CODE']

# %%
wildfire_df
# Out:
#         fire_id      lat       lon        date  hectares  \
# 0             0  50.9050 -126.9292  2000-03-10      6.00
# 1             1  49.2971 -122.2321  2000-08-21      0.20
# 2             2  55.8000 -124.8167  2005-06-20      0.01
# 3             3  49.8770 -121.5730  2000-08-06      0.10
# 4             4  49.0667 -121.8333  2000-07-28      0.10
# ...         ...      ...       ...         ...       ...
# 148758   148756  65.0282 -141.2460  2024-05-15      0.00
# 148759   148757  55.9370 -121.9170  2024-05-12    295.00
# 148760   148758  60.2150 -112.8720  2024-04-26      0.10
# 148761   148759  60.1950 -112.7960  2024-04-26      0.10
# 148762   148760  60.3920 -117.8960  2024-05-05      3.00
#
#                  STATION_NAME PROV_STATE_TERR_CODE  LATITUDE  LONGITUDE  \
# 0                  EGG ISLAND                   BC   50.9050  -126.9292
# 1                   PITT LAKE                   BC   49.2971  -122.2321
# 2              MESILINKA CAMP                   BC   55.8000  -124.8167
# 3                    LYTTON A                   BC   49.8770  -121.5730
# 4        VEDDER SOUTH LICKMAN                   BC   49.0667  -121.8333
# ...                       ...                  ...       ...        ...
# 148758          CLINTON CREEK                   YT   65.0282  -141.2460
# 148759  HUDSON HOPE BCHPA DAM                   BC   55.9370  -121.9170
# 148760             BEAR TOWER                   NT   60.2150  -112.8720
# 148761             BEAR TOWER                   NT   60.1950  -112.7960
# 148762          CAMERON HILLS                   NT   60.3920  -117.8960
#
#         ELEVATION  ...  TOTAL_PRECIPITATION_FLAG SPEED_MAX_GUST_FLAG  \
# 0            14.0  ...                       NaN                 NaN
# 1             7.6  ...                       NaN                 NaN
# 2           803.0  ...                       NaN                 NaN
# 3           224.9  ...                       NaN                 NaN
# 4            15.2  ...                       NaN                 NaN
# ...           ...  ...                       ...                 ...
# 148758      576.1  ...                       NaN                 NaN
# 148759      678.2  ...                       NaN                 NaN
# 148760      213.4  ...                       NaN                 NaN
# 148761      213.4  ...                       NaN                 NaN
# 148762      841.2  ...                       NaN                 NaN
#
#         LOCAL_YEAR TOTAL_RAIN MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  \
# 0           2000.0        3.5                   NaN              NaN
# 1              NaN        NaN                   NaN              NaN
# 2              NaN        NaN                   NaN              NaN
# 3              NaN        NaN                   NaN              NaN
# 4              NaN        NaN                   NaN              NaN
# ...            ...        ...                   ...              ...
# 148758         NaN        NaN                   NaN              NaN
# 148759         NaN        NaN                   NaN              NaN
# 148760         NaN        NaN                   NaN              NaN
# 148761         NaN        NaN                   NaN              NaN
# 148762         NaN        NaN                   NaN              NaN
#
#         HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 0                            NaN                  3.5             0.0
# 1                            NaN                  NaN             NaN
# 2                            NaN                  NaN             NaN
# 3                            NaN                  NaN             NaN
# 4                            NaN                  NaN             NaN
# ...                          ...                  ...             ...
# 148758                       NaN                  NaN             NaN
# 148759                       NaN                  NaN             NaN
# 148760                       NaN                  NaN             NaN
# 148761                       NaN                  NaN             NaN
# 148762                       NaN                  NaN             NaN
#
#        CLIMATE_IDENTIFIER
# 0                 1062646
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 148758                NaN
# 148759                NaN
# 148760                NaN
# 148761                NaN
# 148762                NaN
#
# [148761 rows x 44 columns]

# %% [markdown]
# We will proceed to drop columns that are not necessary to train the model. The `date` column corresponds to the original date of the wildfire, but this column is already contained in the queried weather data in `LOCAL_DATE` so we will drop it. Additionally, `PROV_STATE_TERR_CODE` is a duplicate of the `PROVINCE_CODE` column from queried data.

# %%
# Drop fire_id, lat, lon, date, PROV_STATE_TERR_CODE
wildfire_df = wildfire_df.drop(columns=['fire_id', 'lat', 'lon', 'date', 'distance', 'PROV_STATE_TERR_CODE'])

# %%
wildfire_df
# Out:
#         hectares           STATION_NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0           6.00             EGG ISLAND   50.9050  -126.9292       14.0
# 1           0.20              PITT LAKE   49.2971  -122.2321        7.6
# 2           0.01         MESILINKA CAMP   55.8000  -124.8167      803.0
# 3           0.10               LYTTON A   49.8770  -121.5730      224.9
# 4           0.10   VEDDER SOUTH LICKMAN   49.0667  -121.8333       15.2
# ...          ...                    ...       ...        ...        ...
# 148758      0.00          CLINTON CREEK   65.0282  -141.2460      576.1
# 148759    295.00  HUDSON HOPE BCHPA DAM   55.9370  -121.9170      678.2
# 148760      0.10             BEAR TOWER   60.2150  -112.8720      213.4
# 148761      0.10             BEAR TOWER   60.1950  -112.7960      213.4
# 148762      3.00          CAMERON HILLS   60.3920  -117.8960      841.2
#
#        PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                 BC                 11.3             NaN
# 1                 BC                  NaN             NaN
# 2                 BC                  NaN             NaN
# 3                 BC                  NaN             NaN
# 4                 BC                  NaN             NaN
# ...              ...                  ...             ...
# 148758            YT                  NaN             NaN
# 148759            BC                  NaN             NaN
# 148760            NT                  NaN             NaN
# 148761            NT                  NaN             NaN
# 148762            NT                  NaN             NaN
#
#        DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  \
# 0                          NaN                 NaN  ...
# 1                          NaN                 NaN  ...
# 2                          NaN                 NaN  ...
# 3                          NaN                 NaN  ...
# 4                          NaN                 NaN  ...
# ...                        ...                 ...  ...
# 148758                     NaN                 NaN  ...
# 148759                     NaN                 NaN  ...
# 148760                     NaN                 NaN  ...
# 148761                     NaN                 NaN  ...
# 148762                     NaN                 NaN  ...
#
#         TOTAL_PRECIPITATION_FLAG  SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 0                            NaN                  NaN      2000.0        3.5
# 1                            NaN                  NaN         NaN        NaN
# 2                            NaN                  NaN         NaN        NaN
# 3                            NaN                  NaN         NaN        NaN
# 4                            NaN                  NaN         NaN        NaN
# ...                          ...                  ...         ...        ...
# 148758                       NaN                  NaN         NaN        NaN
# 148759                       NaN                  NaN         NaN        NaN
# 148760                       NaN                  NaN         NaN        NaN
# 148761                       NaN                  NaN         NaN        NaN
# 148762                       NaN                  NaN         NaN        NaN
#
#        MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 0                        NaN              NaN                       NaN
# 1                        NaN              NaN                       NaN
# 2                        NaN              NaN                       NaN
# 3                        NaN              NaN                       NaN
# 4                        NaN              NaN                       NaN
# ...                      ...              ...                       ...
# 148758                   NaN              NaN                       NaN
# 148759                   NaN              NaN                       NaN
# 148760                   NaN              NaN                       NaN
# 148761                   NaN              NaN                       NaN
# 148762                   NaN              NaN                       NaN
#
#         TOTAL_PRECIPITATION SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 0                       3.5            0.0            1062646
# 1                       NaN            NaN                NaN
# 2                       NaN            NaN                NaN
# 3                       NaN            NaN                NaN
# 4                       NaN            NaN                NaN
# ...                     ...            ...                ...
# 148758                  NaN            NaN                NaN
# 148759                  NaN            NaN                NaN
# 148760                  NaN            NaN                NaN
# 148761                  NaN            NaN                NaN
# 148762                  NaN            NaN                NaN
#
# [148761 rows x 38 columns]

# %%
# We drop PROV_STATE_TERR_CODE because it is a duplicated column from the wildfire dataset, but we remove it to use station province
no_wildfire_df = no_wildfire_df.drop(columns=['PROV_STATE_TERR_CODE'])

# %%
no_wildfire_df
# Out:
#        hectares        STATION_NAME  LATITUDE   LONGITUDE  ELEVATION  \
# 0             0          EGG ISLAND   51.1450 -127.500730       14.0
# 1             0          SAMBAA K'E   60.2627 -121.142000      498.0
# 2             0          SAMBAA K'E   60.2627 -121.142000      498.0
# 3             0      FORT NELSON UA   58.5029 -122.342207      378.3
# 4             0          PETITOT LO   59.3200 -119.370000      777.2
# ...         ...                 ...       ...         ...        ...
# 34059         0  YELLOW GRASS NORTH       NaN         NaN        NaN
# 34060         0           YOHO PARK       NaN         NaN        NaN
# 34061         0           YORKTON A       NaN         NaN        NaN
# 34062         0   YORKTON RCMP SNOW       NaN         NaN        NaN
# 34063         0     YOUNGSTOWN AGCM       NaN         NaN        NaN
#
#        LOCAL_MONTH  LOCAL_DAY  DIRECTION_MAX_GUST MIN_REL_HUMIDITY_FLAG  \
# 0              1.0       20.0                 NaN                   NaN
# 1              5.0        8.0                 NaN                   NaN
# 2              5.0       22.0                 NaN                   NaN
# 3              4.0       24.0                 NaN                   NaN
# 4              5.0        7.0                 NaN                   NaN
# ...            ...        ...                 ...                   ...
# 34059          1.0       25.0                32.0                   NaN
# 34060          8.0        2.0                 NaN                   NaN
# 34061          2.0       19.0                 0.0                     M
# 34062          1.0       31.0                 NaN                   NaN
# 34063          6.0       25.0                21.0                   NaN
#
#        LOCAL_YEAR  ... HEATING_DEGREE_DAYS_FLAG  TOTAL_SNOW_FLAG  \
# 0          2000.0  ...                      NaN              NaN
# 1          2000.0  ...                      NaN              NaN
# 2          2000.0  ...                      NaN              NaN
# 3          2001.0  ...                      NaN              NaN
# 4          2000.0  ...                        M                M
# ...           ...  ...                      ...              ...
# 34059      2017.0  ...                      NaN                M
# 34060      2000.0  ...                        M                M
# 34061      2000.0  ...                      NaN              NaN
# 34062      2010.0  ...                      NaN              NaN
# 34063      2018.0  ...                      NaN              NaN
#
#                 LOCAL_DATE MIN_TEMPERATURE  PROVINCE_CODE SPEED_MAX_GUST_FLAG  \
# 0      2000-01-20 00:00:00            -1.3             BC                 NaN
# 1      2000-05-08 00:00:00            -2.2             NT                 NaN
# 2      2000-05-22 00:00:00            -0.9             NT                 NaN
# 3      2001-04-24 00:00:00             0.4             BC                 NaN
# 4      2000-05-07 00:00:00             NaN             AB                 NaN
# ...                    ...             ...            ...                 ...
# 34059  2017-01-25 00:00:00           -14.5             SK                 NaN
# 34060  2000-08-02 00:00:00             NaN             BC                   M
# 34061  2000-02-19 00:00:00           -16.5             SK                 NaN
# 34062  2010-01-31 00:00:00             NaN             SK                 NaN
# 34063  2018-06-25 00:00:00            14.3             AB                 NaN
#
#        SPEED_MAX_GUST  MAX_TEMPERATURE MEAN_TEMPERATURE_FLAG  \
# 0                 NaN              3.3                   NaN
# 1                 NaN             14.5                   NaN
# 2                 NaN             15.1                   NaN
# 3                 NaN             18.5                   NaN
# 4                 NaN              NaN                     M
# ...               ...              ...                   ...
# 34059            32.0             -7.9                   NaN
# 34060             NaN              NaN                     M
# 34061             0.0             -2.7                   NaN
# 34062             NaN              NaN                   NaN
# 34063            44.0             31.2                   NaN
#
#       SNOW_ON_GROUND_FLAG
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 34059                 NaN
# 34060                 NaN
# 34061                 NaN
# 34062                 NaN
# 34063                 NaN
#
# [27056 rows x 38 columns]

# %% [markdown]
# Now that both datasets have the same columns, we will concatenate them into a single dataset

# %%
df = pd.concat([wildfire_df, no_wildfire_df])

# %%
df
# Out:
#        hectares          STATION_NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0          6.00            EGG ISLAND   50.9050  -126.9292       14.0
# 1          0.20             PITT LAKE   49.2971  -122.2321        7.6
# 2          0.01        MESILINKA CAMP   55.8000  -124.8167      803.0
# 3          0.10              LYTTON A   49.8770  -121.5730      224.9
# 4          0.10  VEDDER SOUTH LICKMAN   49.0667  -121.8333       15.2
# ...         ...                   ...       ...        ...        ...
# 34059      0.00    YELLOW GRASS NORTH       NaN        NaN        NaN
# 34060      0.00             YOHO PARK       NaN        NaN        NaN
# 34061      0.00             YORKTON A       NaN        NaN        NaN
# 34062      0.00     YORKTON RCMP SNOW       NaN        NaN        NaN
# 34063      0.00       YOUNGSTOWN AGCM       NaN        NaN        NaN
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                BC                 11.3             NaN
# 1                BC                  NaN             NaN
# 2                BC                  NaN             NaN
# 3                BC                  NaN             NaN
# 4                BC                  NaN             NaN
# ...             ...                  ...             ...
# 34059            SK                 29.2               M
# 34060            BC                  NaN               M
# 34061            SK                 27.6             NaN
# 34062            SK                  NaN             NaN
# 34063            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  \
# 0                         NaN                 NaN  ...
# 1                         NaN                 NaN  ...
# 2                         NaN                 NaN  ...
# 3                         NaN                 NaN  ...
# 4                         NaN                 NaN  ...
# ...                       ...                 ...  ...
# 34059                     NaN                32.0  ...
# 34060                       M                 NaN  ...
# 34061                     NaN                 0.0  ...
# 34062                     NaN                 NaN  ...
# 34063                     NaN                21.0  ...
#
#        TOTAL_PRECIPITATION_FLAG  SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 0                           NaN                  NaN      2000.0        3.5
# 1                           NaN                  NaN         NaN        NaN
# 2                           NaN                  NaN         NaN        NaN
# 3                           NaN                  NaN         NaN        NaN
# 4                           NaN                  NaN         NaN        NaN
# ...                         ...                  ...         ...        ...
# 34059                       NaN                  NaN      2017.0        NaN
# 34060                       NaN                    M      2000.0        NaN
# 34061                       NaN                  NaN      2000.0        0.0
# 34062                       NaN                  NaN      2010.0        0.0
# 34063                       NaN                  NaN      2018.0        NaN
#
#       MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 0                       NaN              NaN                       NaN
# 1                       NaN              NaN                       NaN
# 2                       NaN              NaN                       NaN
# 3                       NaN              NaN                       NaN
# 4                       NaN              NaN                       NaN
# ...                     ...              ...                       ...
# 34059                   NaN                M                       NaN
# 34060                   NaN                M                         M
# 34061                     M              NaN                       NaN
# 34062                   NaN              NaN                       NaN
# 34063                   NaN              NaN                       NaN
#
#        TOTAL_PRECIPITATION SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 0                      3.5            0.0            1062646
# 1                      NaN            NaN                NaN
# 2                      NaN            NaN                NaN
# 3                      NaN            NaN                NaN
# 4                      NaN            NaN                NaN
# ...                    ...            ...                ...
# 34059                  0.0           10.0            4019041
# 34060                  0.2            NaN            11790J1
# 34061                  0.0            6.0            4019080
# 34062                  0.0           25.0            4019095
# 34063                  0.0            NaN            3017705
#
# [175817 rows x 38 columns]

# %% [markdown]
# ## Explore missing data
# In this section, we would like to explore missing data. It is often the case that certain climate stations do not offer climate data for the day we are looking for. Every weather data entry contains a column `ID`, but there may be missing other climate entries such as temperature. If a wildfire does not have an associated `ID`, it is because there is simply not any weather data entry at all at that date at that specific climate station

# %%
missing_id = df['ID'].isnull().sum()
missing_percent = missing_id / len(df) * 100

# %%
missing_percent
# Out:
# np.float64(64.15932475244146)

# %% [markdown]
# We can see that around 64% of weather points do not have corresponding weather data entries. Since we have over 140000 entries, we will drop all wildfires with no data

# %%
df = df.dropna(subset=['ID'])

# %% [markdown]
# Read wildfire dataset without missing weather data

# %%
len(df)
# Out:
# 63014

# %% [markdown]
# We are still left with 63000 weather points to explore. However, even amongst the entries that do have climate data, there are many columns that are missing. Some stations do not offer climate data

# %%
df
# Out:
#        hectares        STATION_NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0           6.0          EGG ISLAND   50.9050  -126.9292       14.0
# 11       1000.0          SAMBAA K'E   59.9617  -121.3608      498.0
# 12         12.0          SAMBAA K'E   59.9752  -121.0342      498.0
# 13          5.0      FORT NELSON UA   59.1767  -122.0190      378.3
# 24          0.1          PETITOT LO   59.4008  -120.6438      777.2
# ...         ...                 ...       ...        ...        ...
# 34059       0.0  YELLOW GRASS NORTH       NaN        NaN        NaN
# 34060       0.0           YOHO PARK       NaN        NaN        NaN
# 34061       0.0           YORKTON A       NaN        NaN        NaN
# 34062       0.0   YORKTON RCMP SNOW       NaN        NaN        NaN
# 34063       0.0     YOUNGSTOWN AGCM       NaN        NaN        NaN
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                BC                 11.3             NaN
# 11               NT                  0.5             NaN
# 12               NT                  2.6             NaN
# 13               BC                  0.3             NaN
# 24               AB                  2.0             NaN
# ...             ...                  ...             ...
# 34059            SK                 29.2               M
# 34060            BC                  NaN               M
# 34061            SK                 27.6             NaN
# 34062            SK                  NaN             NaN
# 34063            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  \
# 0                         NaN                 NaN  ...
# 11                        NaN                 NaN  ...
# 12                        NaN                 NaN  ...
# 13                        NaN                 NaN  ...
# 24                        NaN                 NaN  ...
# ...                       ...                 ...  ...
# 34059                     NaN                32.0  ...
# 34060                       M                 NaN  ...
# 34061                     NaN                 0.0  ...
# 34062                     NaN                 NaN  ...
# 34063                     NaN                21.0  ...
#
#        TOTAL_PRECIPITATION_FLAG  SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 0                           NaN                  NaN      2000.0        3.5
# 11                          NaN                  NaN      2000.0        NaN
# 12                          NaN                  NaN      2000.0        NaN
# 13                            T                  NaN      2001.0        0.0
# 24                          NaN                  NaN      2000.0        1.2
# ...                         ...                  ...         ...        ...
# 34059                       NaN                  NaN      2017.0        NaN
# 34060                       NaN                    M      2000.0        NaN
# 34061                       NaN                  NaN      2000.0        0.0
# 34062                       NaN                  NaN      2010.0        0.0
# 34063                       NaN                  NaN      2018.0        NaN
#
#       MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 0                       NaN              NaN                       NaN
# 11                      NaN              NaN                       NaN
# 12                      NaN              NaN                       NaN
# 13                      NaN                T                       NaN
# 24                      NaN              NaN                       NaN
# ...                     ...              ...                       ...
# 34059                   NaN                M                       NaN
# 34060                   NaN                M                         M
# 34061                     M              NaN                       NaN
# 34062                   NaN              NaN                       NaN
# 34063                   NaN              NaN                       NaN
#
#        TOTAL_PRECIPITATION SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 0                      3.5            0.0            1062646
# 11                     NaN            0.0            220CQHR
# 12                     NaN            0.0            220CQHR
# 13                     0.0            0.0            1192950
# 24                     1.2            0.0            3075171
# ...                    ...            ...                ...
# 34059                  0.0           10.0            4019041
# 34060                  0.2            NaN            11790J1
# 34061                  0.0            6.0            4019080
# 34062                  0.0           25.0            4019095
# 34063                  0.0            NaN            3017705
#
# [63014 rows x 38 columns]

# %%
# Heatmap of missing values
plt.figure(figsize=(16, 6))
ax = sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing values for every column')
plt.show()

# %%
# Bar plot of missing values
missing_values = df.isnull().sum().sort_values(ascending=True)
missing_values.plot(kind='bar', color='skyblue', figsize=(14, 6))
plt.title('Missing values per column')
plt.xlabel('Column')
plt.ylabel('Missing values count')
plt.show()

# %%
missing_values = df.isnull().sum()
missing_percentage = missing_values / len(df) * 100
missing_percentage_df = pd.DataFrame({
    'missing_percentage': missing_percentage,
    'missing-values': missing_values
})
missing_percentage_df.sort_values('missing_percentage', ascending=False, inplace=True)

# %%
missing_percentage_df
# Out:
#                           missing_percentage  missing-values
# MAX_REL_HUMIDITY_FLAG              95.426413           60132
# MIN_REL_HUMIDITY_FLAG              95.415305           60125
# MAX_TEMPERATURE_FLAG               95.156632           59962
# MIN_TEMPERATURE_FLAG               94.593265           59607
# SPEED_MAX_GUST_FLAG                93.069794           58647
# DIRECTION_MAX_GUST_FLAG            92.982512           58592
# MEAN_TEMPERATURE_FLAG              91.660583           57759
# HEATING_DEGREE_DAYS_FLAG           91.660583           57759
# COOLING_DEGREE_DAYS_FLAG           91.660583           57759
# SNOW_ON_GROUND_FLAG                90.879804           57267
# TOTAL_PRECIPITATION_FLAG           86.266544           54360
# MIN_REL_HUMIDITY                   77.193957           48643
# MAX_REL_HUMIDITY                   77.182848           48636
# TOTAL_SNOW_FLAG                    76.059288           47928
# TOTAL_RAIN_FLAG                    74.145428           46722
# DIRECTION_MAX_GUST                 68.837084           43377
# SPEED_MAX_GUST                     68.735519           43313
# SNOW_ON_GROUND                     43.477640           27397
# TOTAL_RAIN                         37.712254           23764
# TOTAL_SNOW                         37.432951           23588
# TOTAL_PRECIPITATION                11.195925            7055
# COOLING_DEGREE_DAYS                10.651601            6712
# MEAN_TEMPERATURE                   10.651601            6712
# HEATING_DEGREE_DAYS                10.651601            6712
# MIN_TEMPERATURE                     6.768337            4265
# MAX_TEMPERATURE                     6.657251            4195
# ELEVATION                           3.342114            2106
# LATITUDE                            2.310598            1456
# LONGITUDE                           2.310598            1456
# hectares                            0.000000               0
# PROVINCE_CODE                       0.000000               0
# STATION_NAME                        0.000000               0
# LOCAL_MONTH                         0.000000               0
# ID                                  0.000000               0
# LOCAL_DATE                          0.000000               0
# LOCAL_DAY                           0.000000               0
# LOCAL_YEAR                          0.000000               0
# CLIMATE_IDENTIFIER                  0.000000               0

# %% [markdown]
# Columns with the highest percentage of NaN values are ones with `FLAG`, which is normal because a flag is only present under a specific condition
#
# Certain features that we care about are also missing in large quantities: Snow (44%), max/min humidity (78%), total rain (36%), total precipitation (10%), total snow (36%), speed of max gust (70%), direction of max gust (70%), max/min temperature (6%), mean temperature (11%)

# %%
df.describe()
# Out:
#             hectares      LATITUDE     LONGITUDE     ELEVATION  \
# count   63014.000000  61558.000000  61558.000000  60908.000000
# mean      259.288441     52.408774   -102.074234    507.539075
# std      5319.412697      4.705389     20.745942    404.315282
# min         0.000000     40.065300   -162.480000      1.200000
# 25%         0.000000     49.212300   -117.669450    224.100000
# 50%         0.009000     51.829461   -111.302250    409.700000
# 75%         0.200000     55.453692    -85.260000    698.000000
# max    577646.800000     82.310400    116.188000   2926.100000
#
#        HEATING_DEGREE_DAYS  DIRECTION_MAX_GUST  MAX_REL_HUMIDITY  \
# count         56302.000000        19637.000000      14378.000000
# mean              7.193212           13.307786         87.863542
# std               8.316091           12.981876         11.280073
# min               0.000000            0.000000         22.000000
# 25%               0.000000            0.000000         83.000000
# 50%               4.400000           12.000000         91.000000
# 75%              11.400000           26.000000         96.000000
# max              62.800000           36.000000        100.000000
#
#           LOCAL_DAY   LOCAL_MONTH  MIN_TEMPERATURE    TOTAL_SNOW  \
# count  63014.000000  63014.000000     58749.000000  39426.000000
# mean      15.513695      5.855350         4.821539      0.165612
# std        8.804715      1.796957         8.848449      1.301654
# min        1.000000      1.000000       -46.900000      0.000000
# 25%        8.000000      5.000000         0.000000      0.000000
# 50%       15.000000      6.000000         6.500000      0.000000
# 75%       23.000000      7.000000        11.000000      0.000000
# max       31.000000     12.000000        26.500000     38.600000
#
#        MEAN_TEMPERATURE  SPEED_MAX_GUST  MIN_REL_HUMIDITY  \
# count      56302.000000    19701.000000      14371.000000
# mean          11.561746       26.713720         41.907105
# std            9.105216       22.533338         17.452596
# min          -44.800000        0.000000          8.000000
# 25%            6.600000        0.000000         29.000000
# 50%           13.600000       33.000000         39.000000
# 75%           18.100000       43.000000         52.000000
# max           34.400000      149.000000        100.000000
#
#        COOLING_DEGREE_DAYS  MAX_TEMPERATURE    LOCAL_YEAR    TOTAL_RAIN  \
# count         56302.000000     58819.000000  63014.000000  39250.000000
# mean              0.754957        18.335252   2008.998270      1.792642
# std               1.698901         9.905606      6.652422      4.997647
# min               0.000000       -42.700000   1999.000000      0.000000
# 25%               0.000000        12.950000   2003.000000      0.000000
# 50%               0.000000        20.500000   2007.000000      0.000000
# 75%               0.100000        25.500000   2014.000000      1.000000
# max              16.400000        47.900000   2024.000000    168.000000
#
#        TOTAL_PRECIPITATION  SNOW_ON_GROUND
# count         55959.000000    35617.000000
# mean              1.859651        4.595036
# std               5.030521       15.632645
# min               0.000000        0.000000
# 25%               0.000000        0.000000
# 50%               0.000000        0.000000
# 75%               1.200000        0.000000
# max             168.000000      322.000000

# %% [markdown]
# ## Imputing data
# First, we want to associate the fill in the missing `LONGITUDE` and `LATITUDE` with the appropriate weather stations in `stations.csv`

# %%
stations_df = pd.read_csv('stations.csv')

# %%
# Convert longitude/latitude
stations_df['LATITUDE'] = stations_df['LATITUDE'] / 10000000
stations_df['LONGITUDE'] = stations_df['LONGITUDE'] / 10000000

# %%
merged_df = pd.merge(df, stations_df, on='STATION_NAME', how='left', suffixes=('_weather', '_station'))

# %%
merged_df
# Out:
#        hectares        STATION_NAME  LATITUDE_weather  LONGITUDE_weather  \
# 0           6.0          EGG ISLAND           50.9050          -126.9292
# 1           6.0          EGG ISLAND           50.9050          -126.9292
# 2        1000.0          SAMBAA K'E           59.9617          -121.3608
# 3          12.0          SAMBAA K'E           59.9752          -121.0342
# 4           5.0      FORT NELSON UA           59.1767          -122.0190
# ...         ...                 ...               ...                ...
# 86270       0.0  YELLOW GRASS NORTH               NaN                NaN
# 86271       0.0           YOHO PARK               NaN                NaN
# 86272       0.0           YORKTON A               NaN                NaN
# 86273       0.0   YORKTON RCMP SNOW               NaN                NaN
# 86274       0.0     YOUNGSTOWN AGCM               NaN                NaN
#
#        ELEVATION_weather PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                   14.0            BC                 11.3             NaN
# 1                   14.0            BC                 11.3             NaN
# 2                  498.0            NT                  0.5             NaN
# 3                  498.0            NT                  2.6             NaN
# 4                  378.3            BC                  0.3             NaN
# ...                  ...           ...                  ...             ...
# 86270                NaN            SK                 29.2               M
# 86271                NaN            BC                  NaN               M
# 86272                NaN            SK                 27.6             NaN
# 86273                NaN            SK                  NaN             NaN
# 86274                NaN            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...            LAST_DATE  \
# 0                         NaN                 NaN  ...  2024-07-15 12:30:02
# 1                         NaN                 NaN  ...  2024-07-14 00:00:00
# 2                         NaN                 NaN  ...  2024-07-15 12:30:02
# 3                         NaN                 NaN  ...  2024-07-15 12:30:02
# 4                         NaN                 NaN  ...  2017-09-18 00:00:00
# ...                       ...                 ...  ...                  ...
# 86270                     NaN                32.0  ...  2024-07-15 12:30:02
# 86271                       M                 NaN  ...  2024-07-15 12:30:02
# 86272                     NaN                 0.0  ...  2005-10-31 00:00:00
# 86273                     NaN                 NaN  ...  2013-04-29 00:00:00
# 86274                     NaN                21.0  ...  2024-05-06 10:00:00
#
#             HLY_FIRST_DATE        HLY_LAST_DATE       DLY_FIRST_DATE  \
# 0      1993-09-17 17:00:00  2024-07-15 12:30:02  2001-06-11 00:00:00
# 1      1969-12-31 16:00:00  2001-12-13 16:00:00  1965-12-01 00:00:00
# 2      1994-02-01 00:00:00  2024-07-15 12:30:02  1994-05-17 00:00:00
# 3      1994-02-01 00:00:00  2024-07-15 12:30:02  1994-05-17 00:00:00
# 4                      NaN                  NaN  1999-04-01 00:00:00
# ...                    ...                  ...                  ...
# 86270  2016-11-23 14:00:00  2024-07-15 12:30:02  2016-11-24 00:00:00
# 86271  1994-02-01 00:00:00  2024-07-15 12:30:02  1992-11-01 00:00:00
# 86272  1953-01-01 00:00:00  2005-10-05 00:00:00  1941-05-01 00:00:00
# 86273                  NaN                  NaN  2004-10-01 00:00:00
# 86274  2012-02-01 00:00:00  2024-05-06 10:00:00  2018-05-14 00:00:00
#
#              DLY_LAST_DATE       MLY_FIRST_DATE        MLY_LAST_DATE  \
# 0      2024-07-15 00:00:00  2005-11-01 00:00:00  2007-03-01 00:00:00
# 1      2024-07-14 00:00:00  1965-01-01 00:00:00  2007-02-01 00:00:00
# 2      2024-07-15 00:00:00  2006-06-01 00:00:00  2007-02-01 00:00:00
# 3      2024-07-15 00:00:00  2006-06-01 00:00:00  2007-02-01 00:00:00
# 4      2017-09-18 00:00:00  1999-04-01 00:00:00  2007-02-01 00:00:00
# ...                    ...                  ...                  ...
# 86270  2024-07-15 00:00:00                  NaN                  NaN
# 86271  2024-07-15 00:00:00  1993-06-01 00:00:00  2006-09-01 00:00:00
# 86272  2005-10-31 00:00:00  1941-01-01 00:00:00  2005-10-01 00:00:00
# 86273  2013-04-29 00:00:00  2007-10-01 00:00:00  2007-11-01 00:00:00
# 86274  2024-05-06 00:00:00                  NaN                  NaN
#
#        HAS_MONTHLY_SUMMARY HAS_NORMALS_DATA HAS_HOURLY_DATA
# 0                        Y                N               N
# 1                        Y                Y               N
# 2                        Y                N               N
# 3                        Y                N               N
# 4                        Y                N               N
# ...                    ...              ...             ...
# 86270                    Y                N               N
# 86271                    Y                N               N
# 86272                    Y                Y               Y
# 86273                    Y                N               N
# 86274                    Y                N               N
#
# [86275 rows x 69 columns]

# %%
df.loc[:, 'LONGITUDE'] = df.loc[:, 'LONGITUDE'].fillna(merged_df['LONGITUDE_station'])

# %%
df.loc[:, 'LATITUDE'] = df.loc[:, 'LATITUDE'].fillna(merged_df['LATITUDE_station'])

# %%
df.loc[:, 'ELEVATION'] = df.loc[:, 'ELEVATION'].fillna(merged_df['ELEVATION_station'])

# %%
df
# Out:
#        hectares        STATION_NAME   LATITUDE   LONGITUDE  ELEVATION  \
# 0           6.0          EGG ISLAND  50.905000 -126.929200       14.0
# 11       1000.0          SAMBAA K'E  59.961700 -121.360800      498.0
# 12         12.0          SAMBAA K'E  59.975200 -121.034200      498.0
# 13          5.0      FORT NELSON UA  59.176700 -122.019000      378.3
# 24          0.1          PETITOT LO  59.400800 -120.643800      777.2
# ...         ...                 ...        ...         ...        ...
# 34059       0.0  YELLOW GRASS NORTH  46.375609  -80.474608      348.0
# 34060       0.0           YOHO PARK  46.375609  -80.474608      348.0
# 34061       0.0           YORKTON A  46.375609  -80.474608      348.0
# 34062       0.0   YORKTON RCMP SNOW  47.491300  -83.204900      448.1
# 34063       0.0     YOUNGSTOWN AGCM  47.491200  -83.204800      448.1
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                BC                 11.3             NaN
# 11               NT                  0.5             NaN
# 12               NT                  2.6             NaN
# 13               BC                  0.3             NaN
# 24               AB                  2.0             NaN
# ...             ...                  ...             ...
# 34059            SK                 29.2               M
# 34060            BC                  NaN               M
# 34061            SK                 27.6             NaN
# 34062            SK                  NaN             NaN
# 34063            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  \
# 0                         NaN                 NaN  ...
# 11                        NaN                 NaN  ...
# 12                        NaN                 NaN  ...
# 13                        NaN                 NaN  ...
# 24                        NaN                 NaN  ...
# ...                       ...                 ...  ...
# 34059                     NaN                32.0  ...
# 34060                       M                 NaN  ...
# 34061                     NaN                 0.0  ...
# 34062                     NaN                 NaN  ...
# 34063                     NaN                21.0  ...
#
#        TOTAL_PRECIPITATION_FLAG  SPEED_MAX_GUST_FLAG  LOCAL_YEAR TOTAL_RAIN  \
# 0                           NaN                  NaN      2000.0        3.5
# 11                          NaN                  NaN      2000.0        NaN
# 12                          NaN                  NaN      2000.0        NaN
# 13                            T                  NaN      2001.0        0.0
# 24                          NaN                  NaN      2000.0        1.2
# ...                         ...                  ...         ...        ...
# 34059                       NaN                  NaN      2017.0        NaN
# 34060                       NaN                    M      2000.0        NaN
# 34061                       NaN                  NaN      2000.0        0.0
# 34062                       NaN                  NaN      2010.0        0.0
# 34063                       NaN                  NaN      2018.0        NaN
#
#       MIN_REL_HUMIDITY_FLAG  TOTAL_RAIN_FLAG  HEATING_DEGREE_DAYS_FLAG  \
# 0                       NaN              NaN                       NaN
# 11                      NaN              NaN                       NaN
# 12                      NaN              NaN                       NaN
# 13                      NaN                T                       NaN
# 24                      NaN              NaN                       NaN
# ...                     ...              ...                       ...
# 34059                   NaN                M                       NaN
# 34060                   NaN                M                         M
# 34061                     M              NaN                       NaN
# 34062                   NaN              NaN                       NaN
# 34063                   NaN              NaN                       NaN
#
#        TOTAL_PRECIPITATION SNOW_ON_GROUND CLIMATE_IDENTIFIER
# 0                      3.5            0.0            1062646
# 11                     NaN            0.0            220CQHR
# 12                     NaN            0.0            220CQHR
# 13                     0.0            0.0            1192950
# 24                     1.2            0.0            3075171
# ...                    ...            ...                ...
# 34059                  0.0           10.0            4019041
# 34060                  0.2            NaN            11790J1
# 34061                  0.0            6.0            4019080
# 34062                  0.0           25.0            4019095
# 34063                  0.0            NaN            3017705
#
# [63014 rows x 38 columns]

# %% [markdown]
# For `TOTAL_RAIN`, `TOTAL_PRECIPITATION`, `SNOW_ON_GROUND`, and `TOTAL_SNOW`, we will fill `NaN` values with 0 because `NaN` in these columns mean there is no snow/rain

# %%
zero_columns = ['TOTAL_RAIN', 'TOTAL_PRECIPITATION', 'SNOW_ON_GROUND', 'TOTAL_SNOW']
df.loc[:, zero_columns] = df.loc[:, zero_columns].fillna(0)

# %% [markdown]
# We impute missing values `MIN_TEMPERATURE`, `MAX_TEMPERATURE` using mean. Do do this, we group the fires by their respective station location (more general than fire location), and compute the mean for each location, and then use that value for missing inputs.

# %%
# Create new coordinates column
df.loc[:, 'COORDINATES'] = df.loc[:, 'LATITUDE'].astype(str) + ',' + df.loc[:, 'LONGITUDE'].astype(str)
# Out:
# C:\Users\ethan\AppData\Local\Temp\ipykernel_2340\4277140737.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'COORDINATES'] = df.loc[:, 'LATITUDE'].astype(str) + ',' + df.loc[:, 'LONGITUDE'].astype(str)

# %%
df
# Out:
#        hectares        STATION_NAME   LATITUDE   LONGITUDE  ELEVATION  \
# 0           6.0          EGG ISLAND  50.905000 -126.929200       14.0
# 11       1000.0          SAMBAA K'E  59.961700 -121.360800      498.0
# 12         12.0          SAMBAA K'E  59.975200 -121.034200      498.0
# 13          5.0      FORT NELSON UA  59.176700 -122.019000      378.3
# 24          0.1          PETITOT LO  59.400800 -120.643800      777.2
# ...         ...                 ...        ...         ...        ...
# 34059       0.0  YELLOW GRASS NORTH  46.375609  -80.474608      348.0
# 34060       0.0           YOHO PARK  46.375609  -80.474608      348.0
# 34061       0.0           YORKTON A  46.375609  -80.474608      348.0
# 34062       0.0   YORKTON RCMP SNOW  47.491300  -83.204900      448.1
# 34063       0.0     YOUNGSTOWN AGCM  47.491200  -83.204800      448.1
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                BC                 11.3             NaN
# 11               NT                  0.5             NaN
# 12               NT                  2.6             NaN
# 13               BC                  0.3             NaN
# 24               AB                  2.0             NaN
# ...             ...                  ...             ...
# 34059            SK                 29.2               M
# 34060            BC                  NaN               M
# 34061            SK                 27.6             NaN
# 34062            SK                  NaN             NaN
# 34063            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  SPEED_MAX_GUST_FLAG  \
# 0                         NaN                 NaN  ...                  NaN
# 11                        NaN                 NaN  ...                  NaN
# 12                        NaN                 NaN  ...                  NaN
# 13                        NaN                 NaN  ...                  NaN
# 24                        NaN                 NaN  ...                  NaN
# ...                       ...                 ...  ...                  ...
# 34059                     NaN                32.0  ...                  NaN
# 34060                       M                 NaN  ...                    M
# 34061                     NaN                 0.0  ...                  NaN
# 34062                     NaN                 NaN  ...                  NaN
# 34063                     NaN                21.0  ...                  NaN
#
#        LOCAL_YEAR  TOTAL_RAIN MIN_REL_HUMIDITY_FLAG TOTAL_RAIN_FLAG  \
# 0          2000.0         3.5                   NaN             NaN
# 11         2000.0         0.0                   NaN             NaN
# 12         2000.0         0.0                   NaN             NaN
# 13         2001.0         0.0                   NaN               T
# 24         2000.0         1.2                   NaN             NaN
# ...           ...         ...                   ...             ...
# 34059      2017.0         0.0                   NaN               M
# 34060      2000.0         0.0                   NaN               M
# 34061      2000.0         0.0                     M             NaN
# 34062      2010.0         0.0                   NaN             NaN
# 34063      2018.0         0.0                   NaN             NaN
#
#        HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 0                           NaN                  3.5             0.0
# 11                          NaN                  0.0             0.0
# 12                          NaN                  0.0             0.0
# 13                          NaN                  0.0             0.0
# 24                          NaN                  1.2             0.0
# ...                         ...                  ...             ...
# 34059                       NaN                  0.0            10.0
# 34060                         M                  0.2             0.0
# 34061                       NaN                  0.0             6.0
# 34062                       NaN                  0.0            25.0
# 34063                       NaN                  0.0             0.0
#
#       CLIMATE_IDENTIFIER           COORDINATES
# 0                1062646      50.905,-126.9292
# 11               220CQHR     59.9617,-121.3608
# 12               220CQHR     59.9752,-121.0342
# 13               1192950      59.1767,-122.019
# 24               3075171     59.4008,-120.6438
# ...                  ...                   ...
# 34059            4019041  46.375609,-80.474608
# 34060            11790J1  46.375609,-80.474608
# 34061            4019080  46.375609,-80.474608
# 34062            4019095      47.4913,-83.2049
# 34063            3017705      47.4912,-83.2048
#
# [63014 rows x 39 columns]

# %%
# Group values by their location, for each location associate mean value for min temp
min_temps = df.groupby('COORDINATES')['MIN_TEMPERATURE'].transform('mean')

# %%
df.loc[:, 'MIN_TEMPERATURE'] = df.loc[:, 'MIN_TEMPERATURE'].fillna(min_temps)

# %%
print(df['MIN_TEMPERATURE'].isnull().sum())
# Out:
# 2882

# %%
# Grouping for max temp
max_temps = df.groupby('COORDINATES')['MAX_TEMPERATURE'].transform('mean')

# %%
df.loc[:, 'MAX_TEMPERATURE'] = df.loc[:, 'MAX_TEMPERATURE'].fillna(max_temps)

# %%
print(df['MAX_TEMPERATURE'].isnull().sum())
# Out:
# 2874

# %% [markdown]
# To impute missing values for `MEAN_TEMPERATURE`, we will average the minimum and maximum temperature for each row

# %%
# Check out missing values of MEAN_TEMP before imputing
missing_means = df[df['MEAN_TEMPERATURE'].isnull()]

# %%
missing_means
# Out:
#        hectares          STATION_NAME   LATITUDE   LONGITUDE  ELEVATION  \
# 131       6.000           HUDSON HOPE  55.835000 -121.672700      491.0
# 135       0.009      FORT ST JOHN 8NW  56.030300 -120.971000      808.0
# 136       0.010          TAYLOR FLATS  56.109800 -120.367600      517.0
# 149      45.000      FORT ST JOHN 8NW  56.021300 -121.008500      808.0
# 174       1.000  MILL BAY 1 SOUTHWEST  55.005700 -129.826300        3.0
# ...         ...                   ...        ...         ...        ...
# 34038     0.000        WINNIPEG SOUTH  48.090000  -80.000000      324.0
# 34040     0.000   WINNIPEG WTC STAPON  48.090000  -80.000000      324.0
# 34051     0.000              WROXETER  48.090000  -80.000000      324.0
# 34060     0.000             YOHO PARK  46.375609  -80.474608      348.0
# 34062     0.000     YORKTON RCMP SNOW  47.491300  -83.204900      448.1
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 131              BC                  NaN             NaN
# 135              BC                  NaN             NaN
# 136              BC                  NaN             NaN
# 149              BC                  NaN             NaN
# 174              BC                  NaN             NaN
# ...             ...                  ...             ...
# 34038            MB                  NaN             NaN
# 34040            MB                  NaN             NaN
# 34051            ON                  NaN               C
# 34060            BC                  NaN               M
# 34062            SK                  NaN             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  SPEED_MAX_GUST_FLAG  \
# 131                       NaN                 NaN  ...                  NaN
# 135                       NaN                 NaN  ...                  NaN
# 136                       NaN                 NaN  ...                  NaN
# 149                       NaN                 NaN  ...                  NaN
# 174                       NaN                 NaN  ...                  NaN
# ...                       ...                 ...  ...                  ...
# 34038                     NaN                 NaN  ...                  NaN
# 34040                     NaN                 NaN  ...                  NaN
# 34051                     NaN                 NaN  ...                  NaN
# 34060                       M                 NaN  ...                    M
# 34062                     NaN                 NaN  ...                  NaN
#
#        LOCAL_YEAR  TOTAL_RAIN MIN_REL_HUMIDITY_FLAG TOTAL_RAIN_FLAG  \
# 131        2001.0         0.0                   NaN             NaN
# 135        2001.0         0.0                   NaN             NaN
# 136        2001.0         4.0                   NaN             NaN
# 149        2000.0         0.0                   NaN             NaN
# 174        2003.0         0.0                   NaN             NaN
# ...           ...         ...                   ...             ...
# 34038      2004.0         0.0                   NaN             NaN
# 34040      2008.0         0.0                   NaN             NaN
# 34051      2005.0         0.0                   NaN             NaN
# 34060      2000.0         0.0                   NaN               M
# 34062      2010.0         0.0                   NaN             NaN
#
#        HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 131                         NaN                  0.0             0.0
# 135                         NaN                  0.0             0.0
# 136                         NaN                  4.0             0.0
# 149                         NaN                  0.0             0.0
# 174                         NaN                  0.0             0.0
# ...                         ...                  ...             ...
# 34038                       NaN                  0.0             0.0
# 34040                       NaN                  0.0            20.0
# 34051                       NaN                  0.0             0.0
# 34060                         M                  0.2             0.0
# 34062                       NaN                  0.0            25.0
#
#       CLIMATE_IDENTIFIER           COORDINATES
# 131              1183629      55.835,-121.6727
# 135              118L0LK      56.0303,-120.971
# 136              1188020     56.1098,-120.3676
# 149              118L0LK     56.0213,-121.0085
# 174              1015136     55.0057,-129.8263
# ...                  ...                   ...
# 34038            502M001           48.09,-80.0
# 34040            5023283           48.09,-80.0
# 34051            6129660           48.09,-80.0
# 34060            11790J1  46.375609,-80.474608
# 34062            4019095      47.4913,-83.2049
#
# [6712 rows x 39 columns]

# %%
# Fill in NaN values with average
df.loc[:, 'MEAN_TEMPERATURE'] = df.loc[:, 'MEAN_TEMPERATURE'].fillna((df.loc[:, 'MAX_TEMPERATURE'] + df.loc[:, 'MIN_TEMPERATURE']) / 2)

# %%
# Check out MEAN_TEMP after imputing
df
# Out:
#        hectares        STATION_NAME   LATITUDE   LONGITUDE  ELEVATION  \
# 0           6.0          EGG ISLAND  50.905000 -126.929200       14.0
# 11       1000.0          SAMBAA K'E  59.961700 -121.360800      498.0
# 12         12.0          SAMBAA K'E  59.975200 -121.034200      498.0
# 13          5.0      FORT NELSON UA  59.176700 -122.019000      378.3
# 24          0.1          PETITOT LO  59.400800 -120.643800      777.2
# ...         ...                 ...        ...         ...        ...
# 34059       0.0  YELLOW GRASS NORTH  46.375609  -80.474608      348.0
# 34060       0.0           YOHO PARK  46.375609  -80.474608      348.0
# 34061       0.0           YORKTON A  46.375609  -80.474608      348.0
# 34062       0.0   YORKTON RCMP SNOW  47.491300  -83.204900      448.1
# 34063       0.0     YOUNGSTOWN AGCM  47.491200  -83.204800      448.1
#
#       PROVINCE_CODE  HEATING_DEGREE_DAYS TOTAL_SNOW_FLAG  \
# 0                BC                 11.3             NaN
# 11               NT                  0.5             NaN
# 12               NT                  2.6             NaN
# 13               BC                  0.3             NaN
# 24               AB                  2.0             NaN
# ...             ...                  ...             ...
# 34059            SK                 29.2               M
# 34060            BC                  NaN               M
# 34061            SK                 27.6             NaN
# 34062            SK                  NaN             NaN
# 34063            AB                  0.0             NaN
#
#       DIRECTION_MAX_GUST_FLAG  DIRECTION_MAX_GUST  ...  SPEED_MAX_GUST_FLAG  \
# 0                         NaN                 NaN  ...                  NaN
# 11                        NaN                 NaN  ...                  NaN
# 12                        NaN                 NaN  ...                  NaN
# 13                        NaN                 NaN  ...                  NaN
# 24                        NaN                 NaN  ...                  NaN
# ...                       ...                 ...  ...                  ...
# 34059                     NaN                32.0  ...                  NaN
# 34060                       M                 NaN  ...                    M
# 34061                     NaN                 0.0  ...                  NaN
# 34062                     NaN                 NaN  ...                  NaN
# 34063                     NaN                21.0  ...                  NaN
#
#        LOCAL_YEAR  TOTAL_RAIN MIN_REL_HUMIDITY_FLAG TOTAL_RAIN_FLAG  \
# 0          2000.0         3.5                   NaN             NaN
# 11         2000.0         0.0                   NaN             NaN
# 12         2000.0         0.0                   NaN             NaN
# 13         2001.0         0.0                   NaN               T
# 24         2000.0         1.2                   NaN             NaN
# ...           ...         ...                   ...             ...
# 34059      2017.0         0.0                   NaN               M
# 34060      2000.0         0.0                   NaN               M
# 34061      2000.0         0.0                     M             NaN
# 34062      2010.0         0.0                   NaN             NaN
# 34063      2018.0         0.0                   NaN             NaN
#
#        HEATING_DEGREE_DAYS_FLAG  TOTAL_PRECIPITATION  SNOW_ON_GROUND  \
# 0                           NaN                  3.5             0.0
# 11                          NaN                  0.0             0.0
# 12                          NaN                  0.0             0.0
# 13                          NaN                  0.0             0.0
# 24                          NaN                  1.2             0.0
# ...                         ...                  ...             ...
# 34059                       NaN                  0.0            10.0
# 34060                         M                  0.2             0.0
# 34061                       NaN                  0.0             6.0
# 34062                       NaN                  0.0            25.0
# 34063                       NaN                  0.0             0.0
#
#       CLIMATE_IDENTIFIER           COORDINATES
# 0                1062646      50.905,-126.9292
# 11               220CQHR     59.9617,-121.3608
# 12               220CQHR     59.9752,-121.0342
# 13               1192950      59.1767,-122.019
# 24               3075171     59.4008,-120.6438
# ...                  ...                   ...
# 34059            4019041  46.375609,-80.474608
# 34060            11790J1  46.375609,-80.474608
# 34061            4019080  46.375609,-80.474608
# 34062            4019095      47.4913,-83.2049
# 34063            3017705      47.4912,-83.2048
#
# [63014 rows x 39 columns]

# %% [markdown]
# ## Feature selection and dropping data
# Features that would make sense to include weather data that could logically directly impact the spread of the wildfire: rain, temperature, humidity, precipitation, snow.
# - While humidity would logically greatly impact the accuracy of the model, 78% of `MIN_REL_HUMIDITY` and `MAX_REL_HUMIDITY` are missing, so we have no choice but to drop these columns
# - Wind would also logically greatly impact the spread of the fire, but 70% of `SPEED_MAX_GUST` is missing and 90% of `DIRECTION_MAX_GUST` is missing
# - Columns with `FLAG` are not useful
# - We will drop `COOLING_DEGREE_DAYS` and `HEATING_DEGREE_DAYS`: they are defined as the number of degree Celsius that the mean temperature is above/below 18 degrees Celsius. Metric is another way of expressing temperature
# - We will hypothesize that location has an impact on areas of wildfire: `LONGITUDE`, `LATITUDE` (location might impact wildfire spread); `ELEVATION` might also be useful. However, due to the way that we queried non-wildfire data (by searching 50 days earlier, lon/lat/elevation will have little impact, since the same spots will always have a wildfire as well as a non-wildfire (0 hectares). However we also queried weather data from unaffected weather stations
# - For weather, we will use `MIN_TEMPERATURE`, `MAX_TEMPERATURE`, `MIN_TEMPERATURE`, `SNOW_ON_GROUND`, `TOTAL_RAIN`, `TOTAL_PRECIPITATION`

# %%
# Drop entries without min/max/mean temperature
df = df.dropna(subset=['MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MEAN_TEMPERATURE'])

# %%
# df = df.dropna(subset=['MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY', 'SPEED_MAX_GUST'])

# %%
missing_values = df.isnull().sum()
missing_percentage = missing_values / len(df) * 100
missing_percentage_df = pd.DataFrame({
    'missing_percentage': missing_percentage,
    'missing-values': missing_values
})
missing_percentage_df.sort_values('missing_percentage', ascending=False, inplace=True)

# %%
missing_percentage_df
# Out:
#                           missing_percentage  missing-values
# MAX_TEMPERATURE_FLAG               97.234313           58080
# MIN_TEMPERATURE_FLAG               96.735418           57782
# MAX_REL_HUMIDITY_FLAG              95.469765           57026
# MIN_REL_HUMIDITY_FLAG              95.458046           57019
# COOLING_DEGREE_DAYS_FLAG           94.024978           56163
# HEATING_DEGREE_DAYS_FLAG           94.024978           56163
# MEAN_TEMPERATURE_FLAG              94.024978           56163
# SPEED_MAX_GUST_FLAG                93.395500           55787
# DIRECTION_MAX_GUST_FLAG            93.306770           55734
# SNOW_ON_GROUND_FLAG                90.981384           54345
# TOTAL_PRECIPITATION_FLAG           87.214558           52095
# TOTAL_SNOW_FLAG                    76.123351           45470
# MIN_REL_HUMIDITY                   76.068104           45437
# MAX_REL_HUMIDITY                   76.056385           45430
# TOTAL_RAIN_FLAG                    74.377218           44427
# DIRECTION_MAX_GUST                 67.774392           40483
# SPEED_MAX_GUST                     67.670595           40421
# HEATING_DEGREE_DAYS                 5.780821            3453
# COOLING_DEGREE_DAYS                 5.780821            3453
# ELEVATION                           0.267863             160
# hectares                            0.000000               0
# STATION_NAME                        0.000000               0
# LATITUDE                            0.000000               0
# PROVINCE_CODE                       0.000000               0
# LONGITUDE                           0.000000               0
# TOTAL_SNOW                          0.000000               0
# MIN_TEMPERATURE                     0.000000               0
# LOCAL_MONTH                         0.000000               0
# LOCAL_DAY                           0.000000               0
# ID                                  0.000000               0
# MEAN_TEMPERATURE                    0.000000               0
# LOCAL_DATE                          0.000000               0
# MAX_TEMPERATURE                     0.000000               0
# LOCAL_YEAR                          0.000000               0
# TOTAL_RAIN                          0.000000               0
# TOTAL_PRECIPITATION                 0.000000               0
# SNOW_ON_GROUND                      0.000000               0
# CLIMATE_IDENTIFIER                  0.000000               0
# COORDINATES                         0.000000               0

# %%
# Heatmap of missing values
plt.figure(figsize=(16, 6))
ax = sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing values for every column')
plt.show()

# %%
# Select columns for final training dataset including date and weather data
clean_df = df[['LATITUDE', 'LONGITUDE', 'ELEVATION', 'STATION_NAME', 'PROVINCE_CODE', 'ID', 'LOCAL_DATE', 'LOCAL_DAY', 'LOCAL_MONTH', 'LOCAL_YEAR', 'MIN_TEMPERATURE', 'MAX_TEMPERATURE', 'MEAN_TEMPERATURE', 'SNOW_ON_GROUND', 'TOTAL_SNOW', 'TOTAL_RAIN', 'TOTAL_PRECIPITATION', 'MIN_REL_HUMIDITY', 'MAX_REL_HUMIDITY', 'SPEED_MAX_GUST', 'hectares']]

# %%
# Since it is a classification problem, we will add a binary target column `FIRE`, that contains whether there was a fire there
clean_df['CLASS'] = (clean_df.loc[:, 'hectares'] > 0).astype(int)
# Out:
# C:\Users\ethan\AppData\Local\Temp\ipykernel_2340\909020681.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['CLASS'] = (clean_df.loc[:, 'hectares'] > 0).astype(int)

# %%
clean_df
# Out:
#         LATITUDE   LONGITUDE  ELEVATION        STATION_NAME PROVINCE_CODE  \
# 0      50.905000 -126.929200       14.0          EGG ISLAND            BC
# 11     59.961700 -121.360800      498.0          SAMBAA K'E            NT
# 12     59.975200 -121.034200      498.0          SAMBAA K'E            NT
# 13     59.176700 -122.019000      378.3      FORT NELSON UA            BC
# 24     59.400800 -120.643800      777.2          PETITOT LO            AB
# ...          ...         ...        ...                 ...           ...
# 34059  46.375609  -80.474608      348.0  YELLOW GRASS NORTH            SK
# 34060  46.375609  -80.474608      348.0           YOHO PARK            BC
# 34061  46.375609  -80.474608      348.0           YORKTON A            SK
# 34062  47.491300  -83.204900      448.1   YORKTON RCMP SNOW            SK
# 34063  47.491200  -83.204800      448.1     YOUNGSTOWN AGCM            AB
#
#                       ID           LOCAL_DATE  LOCAL_DAY  LOCAL_MONTH  \
# 0      1062646.2000.3.10  2000-03-10 00:00:00       10.0          3.0
# 11     220CQHR.2000.6.27  2000-06-27 00:00:00       27.0          6.0
# 12     220CQHR.2000.7.11  2000-07-11 00:00:00       11.0          7.0
# 13     1192950.2001.6.13  2001-06-13 00:00:00       13.0          6.0
# 24     3075171.2000.6.26  2000-06-26 00:00:00       26.0          6.0
# ...                  ...                  ...        ...          ...
# 34059  4019041.2017.1.25  2017-01-25 00:00:00       25.0          1.0
# 34060   11790J1.2000.8.2  2000-08-02 00:00:00        2.0          8.0
# 34061  4019080.2000.2.19  2000-02-19 00:00:00       19.0          2.0
# 34062  4019095.2010.1.31  2010-01-31 00:00:00       31.0          1.0
# 34063  3017705.2018.6.25  2018-06-25 00:00:00       25.0          6.0
#
#        LOCAL_YEAR  ...  MEAN_TEMPERATURE  SNOW_ON_GROUND  TOTAL_SNOW  \
# 0          2000.0  ...          6.700000             0.0         0.0
# 11         2000.0  ...         17.500000             0.0         0.0
# 12         2000.0  ...         15.400000             0.0         0.0
# 13         2001.0  ...         17.700000             0.0         0.0
# 24         2000.0  ...         16.000000             0.0         0.0
# ...           ...  ...               ...             ...         ...
# 34059      2017.0  ...        -11.200000            10.0         0.0
# 34060      2000.0  ...          9.134677             0.0         0.0
# 34061      2000.0  ...         -9.600000             6.0         0.0
# 34062      2010.0  ...          3.652995            25.0         0.0
# 34063      2018.0  ...         22.800000             0.0         0.0
#
#        TOTAL_RAIN  TOTAL_PRECIPITATION  MIN_REL_HUMIDITY  MAX_REL_HUMIDITY  \
# 0             3.5                  3.5               NaN               NaN
# 11            0.0                  0.0               NaN               NaN
# 12            0.0                  0.0               NaN               NaN
# 13            0.0                  0.0               NaN               NaN
# 24            1.2                  1.2               NaN               NaN
# ...           ...                  ...               ...               ...
# 34059         0.0                  0.0               NaN               NaN
# 34060         0.0                  0.2               NaN               NaN
# 34061         0.0                  0.0               NaN               NaN
# 34062         0.0                  0.0               NaN               NaN
# 34063         0.0                  0.0              16.0              95.0
#
#        SPEED_MAX_GUST  hectares  CLASS
# 0                 NaN       6.0      1
# 11                NaN    1000.0      1
# 12                NaN      12.0      1
# 13                NaN       5.0      1
# 24                NaN       0.1      1
# ...               ...       ...    ...
# 34059            32.0       0.0      0
# 34060             NaN       0.0      0
# 34061             0.0       0.0      0
# 34062             NaN       0.0      0
# 34063            44.0       0.0      0
#
# [59732 rows x 22 columns]

# %%
clean_df.to_csv('clean-weather-3.csv', index=False)
